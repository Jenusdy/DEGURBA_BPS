# %%
import glob
from google.cloud import storage
from os.path import exists

# %%
#Download PopDens_100m
from google.cloud import storage

client = storage.Client()
ls_=list(client.list_blobs('bps-gcp-bucket', prefix='Degree of Urbanisation/PopDens'))
storage_client = storage.Client()
for i in ls_:
    if len(str(i).split('/'))==3:
        data_=str(i).split('/')[2].split(',')[0]
        print(data_)
        if (data_!='')and(exists('data/output/1_population_density/'+data_)==False) :
            bucket = storage_client.get_bucket('bps-gcp-bucket')
            source_blob_name='Degree of Urbanisation/PopDens/'+data_
            blob = bucket.blob(source_blob_name)
            blob.download_to_filename('data/output/1_population_density/'+data_)
# Out:
# grid_pop_1101_100m.gpkg
# grid_pop_1101_1km.tif
# grid_pop_1101_1km_w_bu.gpkg
# grid_pop_1102_100m.gpkg
# grid_pop_1102_1km.tif
# grid_pop_1102_1km_w_bu.gpkg
# grid_pop_1103_100m.gpkg
# grid_pop_1103_1km.tif
# grid_pop_1103_1km_w_bu.gpkg
# grid_pop_1104_100m.gpkg
# grid_pop_1104_1km.tif
# grid_pop_1104_1km_w_bu.gpkg
# grid_pop_1105_100m.gpkg
# grid_pop_1105_1km.tif
# grid_pop_1105_1km_w_bu.gpkg
# grid_pop_1106_100m.gpkg
# grid_pop_1106_1km.tif
# grid_pop_1106_1km_w_bu.gpkg
# grid_pop_1107_100m.gpkg
# grid_pop_1107_1km.tif
# grid_pop_1107_1km_w_bu.gpkg
# grid_pop_1108_100m.gpkg
# grid_pop_1108_1km.tif
# grid_pop_1108_1km_w_bu.gpkg
# grid_pop_1109_100m.gpkg
# grid_pop_1109_1km.tif
# grid_pop_1109_1km_w_bu.gpkg
# grid_pop_1110_100m.gpkg
# grid_pop_1110_1km.tif
# grid_pop_1110_1km_w_bu.gpkg
# grid_pop_1111_100m.gpkg
# grid_pop_1111_1km.tif
# grid_pop_1111_1km_w_bu.gpkg
# grid_pop_1112_100m.gpkg
# grid_pop_1112_1km.tif
# grid_pop_1112_1km_w_bu.gpkg
# grid_pop_1113_100m.gpkg
# ...

# %%
#Download Fin_PopDens_1km
from google.cloud import storage

client = storage.Client()
ls_=list(client.list_blobs('bps-gcp-bucket', prefix='Degree of Urbanisation/Fin_1km_and_pulau_podens/'))
storage_client = storage.Client()
for i in ls_:
    if len(str(i).split('/'))==3:
        data_=str(i).split('/')[2].split(',')[0]
        print(data_)
        if (data_!='')and(exists('data/output/1_5_population_density/'+data_)==False) :
            bucket = storage_client.get_bucket('bps-gcp-bucket')
            source_blob_name='Degree of Urbanisation/Fin_1km_and_pulau_podens/'+data_
            blob = bucket.blob(source_blob_name)
            blob.download_to_filename('data/output/1_5_population_density/'+data_)
# Out:
# 00_fin_pulau_BabelKepri_finalized.gpkg
# 00_fin_pulau_Bali_finalized.gpkg
# 00_fin_pulau_Borneo_finalized.gpkg
# 00_fin_pulau_Celebes_finalized.gpkg
# 00_fin_pulau_Java_finalized.gpkg
# 00_fin_pulau_Maluku_finalized.gpkg
# 00_fin_pulau_Malut_finalized.gpkg
# 00_fin_pulau_NTB_finalized.gpkg
# 00_fin_pulau_NTT_finalized.gpkg
# 00_fin_pulau_Papua_finalized.gpkg
# 00_fin_pulau_Sumatera_finalized.gpkg
# 00_pulau_BabelKepri_w_bu.gpkg
# 00_pulau_Bali_w_bu.gpkg
# 00_pulau_Borneo_w_bu.gpkg
# 00_pulau_Celebes_w_bu.gpkg
# 00_pulau_Java_w_bu.gpkg
# 00_pulau_Maluku_w_bu.gpkg
# 00_pulau_Malut_w_bu.gpkg
# 00_pulau_NTB_w_bu.gpkg
# 00_pulau_NTT_w_bu.gpkg
# 00_pulau_Papua_w_bu.gpkg
# 00_pulau_Sumatera_w_bu.gpkg
# 1km_prov11_w_bu.gpkg
# 1km_prov12_w_bu.gpkg
# 1km_prov13_w_bu.gpkg
# 1km_prov14_w_bu.gpkg
# 1km_prov15_w_bu.gpkg
# 1km_prov16_w_bu.gpkg
# 1km_prov17_w_bu.gpkg
# 1km_prov18_w_bu.gpkg
# 1km_prov19_w_bu.gpkg
# 1km_prov21_w_bu.gpkg
# 1km_prov31_w_bu.gpkg
# 1km_prov32_w_bu.gpkg
# ...

# %%
#Download OSM
from google.cloud import storage

client = storage.Client()
ls_=list(client.list_blobs('bps-gcp-bucket', prefix='Degree of Urbanisation/OSM/all-seasoned-road'))
storage_client = storage.Client()
for i in ls_:
    if len(str(i).split('/'))==4:
        data_=str(i).split('/')[3].split(',')[0]
        print(data_)
        if (data_!='')and(exists('data/input/OSM/'+data_)==False) :
            bucket = storage_client.get_bucket('bps-gcp-bucket')
            source_blob_name='Degree of Urbanisation/OSM/all-seasoned-road/'+data_
            blob = bucket.blob(source_blob_name)
            blob.download_to_filename('data/input/OSM/'+data_)
# Out:
# 11_allseasonedroad_OSM.gpkg
# 12_allseasonedroad_OSM.gpkg
# 13_allseasonedroad_OSM.gpkg
# 14_allseasonedroad_OSM.gpkg
# 15_allseasonedroad_OSM.gpkg
# 16_allseasonedroad_OSM.gpkg
# 17_allseasonedroad_OSM.gpkg
# 18_allseasonedroad_OSM.gpkg
# 19_allseasonedroad_OSM.gpkg
# 31_allseasonedroad_OSM.gpkg
# 32_allseasonedroad_OSM.gpkg
# 33_allseasonedroad_OSM.gpkg
# 34_allseasonedroad_OSM.gpkg
# 35_allseasonedroad_OSM.gpkg
# 36_allseasonedroad_OSM.gpkg
# 51_allseasonedroad_OSM.gpkg
# 52_allseasonedroad_OSM.gpkg
# 53_allseasonedroad_OSM.gpkg
# 61_allseasonedroad_OSM.gpkg
# 62_allseasonedroad_OSM.gpkg
# 63_allseasonedroad_OSM.gpkg
# 64_allseasonedroad_OSM.gpkg
# 65_allseasonedroad_OSM.gpkg
# 71_allseasonedroad_OSM.gpkg
# 72_allseasonedroad_OSM.gpkg
# 73_allseasonedroad_OSM.gpkg
# 74_allseasonedroad_OSM.gpkg
# 75_allseasonedroad_OSM.gpkg
# 76_allseasonedroad_OSM.gpkg
# 81_allseasonedroad_OSM.gpkg
# 82_allseasonedroad_OSM.gpkg
# 91_allseasonedroad_OSM.gpkg
# 94_allseasonedroad_OSM.gpkg

# %%
#Download raster data desa
from google.cloud import storage

client = storage.Client()
ls_=list(client.list_blobs('bps-gcp-bucket', prefix='Degree of Urbanisation/RasterDesa/'))
storage_client = storage.Client()
for i in ls_:
    if len(str(i).split('/'))==3:
        data_=str(i).split('/')[2].split(',')[0]
        print(data_)
        if (data_!='')and(exists('data/output/0_raster_data_desa/'+data_)==False) :
            bucket = storage_client.get_bucket('bps-gcp-bucket')
            source_blob_name='Degree of Urbanisation/RasterDesa/'+data_
            blob = bucket.blob(source_blob_name)
            blob.download_to_filename('data/output/0_raster_data_desa/'+data_)
# Out:
# desa_pend_rasterize_11.gpkg
# desa_pend_rasterize_12.gpkg
# desa_pend_rasterize_13.gpkg
# desa_pend_rasterize_14.gpkg
# desa_pend_rasterize_15.gpkg
# desa_pend_rasterize_16.gpkg
# desa_pend_rasterize_17.gpkg
# desa_pend_rasterize_18.gpkg
# desa_pend_rasterize_19.gpkg
# desa_pend_rasterize_21.gpkg
# desa_pend_rasterize_31.gpkg
# desa_pend_rasterize_32.gpkg
# desa_pend_rasterize_33.gpkg
# desa_pend_rasterize_34.gpkg
# desa_pend_rasterize_35.gpkg
# desa_pend_rasterize_36.gpkg
# desa_pend_rasterize_51.gpkg
# desa_pend_rasterize_52.gpkg
# desa_pend_rasterize_53.gpkg
# desa_pend_rasterize_61.gpkg
# desa_pend_rasterize_62.gpkg
# desa_pend_rasterize_63.gpkg
# desa_pend_rasterize_64.gpkg
# desa_pend_rasterize_65.gpkg
# desa_pend_rasterize_71.gpkg
# desa_pend_rasterize_72.gpkg
# desa_pend_rasterize_73.gpkg
# desa_pend_rasterize_74.gpkg
# desa_pend_rasterize_75.gpkg
# desa_pend_rasterize_76.gpkg
# desa_pend_rasterize_81.gpkg
# desa_pend_rasterize_82.gpkg
# desa_pend_rasterize_91.gpkg
# ...
